# %% [markdown]
# ## Shahin Huseyngulu - MJHJHQ

# %% [markdown]
# ### My Neptune is MJHJHQ, so MJHQ and capital letter of my name S from Shahin --> MJHQS -->                     HJMQS (alphabetical order)

# %% [markdown]
# ### (A=0, B=1, C=2...) HJMQS: H => 7, J => 9, M => 12, Q => 16, S=> 18

# %% [markdown]
# ### H=7,  7 mod 10 = 7, and 7+3=10;
# ### J = 9, 9 mod 10 = 9, and 9+3=12;
# ### M=12,  12 mod 10 = 2, and 2+3=5;
# ### Q=16, 16 mod 10 = 6, and 6+3=9;
# ### S=18,  18 mod 10 = 8, and 8+3=11

# %% [markdown]
# ## 1. The clique - H(size=10)

# %%
cat <<EOF>h.dot
graph H {
  node [style=filled, color=blue];
  label = "The clique";
  h1 -- h2;
  h1 -- h3;
  h1 -- h4;
  h1 -- h5;
  h1 -- h6;
  h1 -- h7;
  h1 -- h8;
  h1 -- h9;
  h1 -- h10;
  h2 -- h1;
  h2 -- h3;
  h2 -- h4;
  h2 -- h5;
  h2 -- h6;
  h2 -- h7;
  h2 -- h8;
  h2 -- h9;
  h2 -- h10;
  h3 -- h1;
  h3 -- h2;
  h3 -- h4;
  h3 -- h5;
  h3 -- h6;
  h3 -- h7;
  h3 -- h8;
  h3 -- h9;
  h3 -- h10;
  h4 -- h1;
  h4 -- h2;
  h4 -- h3;
  h4 -- h5;
  h4 -- h6;
  h4 -- h7;
  h4 -- h8;
  h4 -- h9;
  h4 -- h10;
  h5 -- h1;
  h5 -- h2;
  h5 -- h3;
  h5 -- h4;
  h5 -- h6;
  h5 -- h7;
  h5 -- h8;
  h5 -- h9;
  h5 -- h10;
  h6 -- h1;
  h6 -- h2;
  h6 -- h3;
  h6 -- h4;
  h6 -- h5;
  h6 -- h7;
  h6 -- h8;
  h6 -- h9;
  h6 -- h10;
  h7 -- h1;
  h7 -- h2;
  h7 -- h3;
  h7 -- h4;
  h7 -- h5;
  h7 -- h6;
  h7 -- h8;
  h7 -- h9;
  h7 -- h10;
  h8 -- h1;
  h8 -- h2;
  h8 -- h3;
  h8 -- h4;
  h8 -- h5;
  h8 -- h6;
  h8 -- h7;
  h8 -- h9;
  h8 -- h10;
  h9 -- h1;
  h9 -- h2;
  h9 -- h3;
  h9 -- h4;
  h9 -- h5;
  h9 -- h6;
  h9 -- h7;
  h9 -- h8;
  h9 -- h10;
  h10 -- h1;
  h10 -- h2;
  h10 -- h3;
  h10 -- h4;
  h10 -- h5;
  h10 -- h6;
  h10 -- h7;
  h10 -- h8;
  h10 -- h9;
}
EOF

# %%
cat h.dot | circo -Tpng | display

# %% [markdown]
# ## 2. The Star - J(size=12)

# %%
cat <<EOF>j.dot
digraph J {
  node [style=filled, color=red];
  label = "The Star";
  j3 -> j1;
  j3 -> j2;
  j3 -> j4;
  j3 -> j5;
  j3 -> j6;
  j3 -> j7;
  j3 -> j8;
  j3 -> j9;
  j3 -> j10;
  j3 -> 11;
  j3 -> j12;
}
EOF

# %%
''' The most sutied one here is CIRCO, but the most fit one for the clique was circo and I used it for H and therefore I use 
here neato. '''
cat j.dot | neato -Tpng | display
# Out:
# bash: $' The most sutied one here is CIRCO, but the most fit one for the clique was circo and I used it for H and therefore I use \nhere neato. ': command not found

# %% [markdown]
# ### 3. The Ring - M(size=5)

# %%
cat <<EOF>m.dot
digraph M {
  node [style=filled, color=green];
  label = "The Ring I";
  m1 -> m2 -> m3 -> m4 -> m5 -> m1;
}
EOF

# %%
cat m.dot | dot -Tpng | display

# %% [markdown]
# ### 4. The Ring - Q(size=9)

# %%
cat <<EOF>q.dot
graph Q {
  node [style=filled, color=brown];
  label = "The Ring II";
  q1 -- q2 -- q3 -- q4 -- q5 -- q6 -- q7 -- q8 -- q9 -- q1;
}
EOF

# %%
cat q.dot | sfdp -Tpng | display
# Out:
# Error: remove_overlap: Graphviz not built with triangulation library

# %% [markdown]
# ### 5. The Ring - S(size=11)

# %%
cat <<EOF>s.dot
graph S {
  node [style=filled, color=grey];
  label = "The Ring III";
  s1 -- s2 -- s3 -- s4 -- s5 -- s6 -- s7 -- s8 -- s9 -- s10 -- s11 -- s1;
}
EOF

# %%
cat s.dot | fdp -Tpng | display

# %%
# Merged Network of HJMQS
cat <<EOF>merged.dot
graph Merged {
  subgraph clusterH {
    style=filled;
    color=blue;
    node [style=filled, color=blue];
    label = "The clique";
    h1 -- h2;
    h1 -- h3;
    h1 -- h4;
    h1 -- h5;
    h1 -- h6;
    h1 -- h7;
    h1 -- h8;
    h1 -- h9;
    h1 -- h10;
    h2 -- h1;
    h2 -- h3;
    h2 -- h4;
    h2 -- h5;
    h2 -- h6;
    h2 -- h7;
    h2 -- h8;
    h2 -- h9;
    h2 -- h10;
    h3 -- h1;
    h3 -- h2;
    h3 -- h4;
    h3 -- h5;
    h3 -- h6;
    h3 -- h7;
    h3 -- h8;
    h3 -- h9;
    h3 -- h10;
    h4 -- h1;
    h4 -- h2;
    h4 -- h3;
    h4 -- h5;
    h4 -- h6;
    h4 -- h7;
    h4 -- h8;
    h4 -- h9;
    h4 -- h10;
    h5 -- h1;
    h5 -- h2;
    h5 -- h3;
    h5 -- h4;
    h5 -- h6;
    h5 -- h7;
    h5 -- h8;
    h5 -- h9;
    h5 -- h10;
    h6 -- h1;
    h6 -- h2;
    h6 -- h3;
    h6 -- h4;
    h6 -- h5;
    h6 -- h7;
    h6 -- h8;
    h6 -- h9;
    h6 -- h10;
    h7 -- h1;
    h7 -- h2;
    h7 -- h3;
    h7 -- h4;
    h7 -- h5;
    h7 -- h6;
    h7 -- h8;
    h7 -- h9;
    h7 -- h10;
    h8 -- h1;
    h8 -- h2;
    h8 -- h3;
    h8 -- h4;
    h8 -- h5;
    h8 -- h6;
    h8 -- h7;
    h8 -- h9;
    h8 -- h10;
    h9 -- h1;
    h9 -- h2;
    h9 -- h3;
    h9 -- h4;
    h9 -- h5;
    h9 -- h6;
    h9 -- h7;
    h9 -- h8;
    h9 -- h10;
    h10 -- h1;
    h10 -- h2;
    h10 -- h3;
    h10 -- h4;
    h10 -- h5;
    h10 -- h6;
    h10 -- h7;
    h10 -- h8;
    h10 -- h9;
  }
  
  subgraph clusterJ {
    style=filled;
    color=red;
    node [style=filled, color=red];
    label = "The Star";
    j3 -- j1;
    j3 -- j2;
    j3 -- j4;
    j3 -- j5;
    j3 -- j6;
    j3 -- j7;
    j3 -- j8;
    j3 -- j9;
    j3 -- j10;
    j3 -- 11;
    j3 -- j12;
    label = "process #2";
  }
  
  subgraph clusterM {
    style=filled;
    color=green;
    node [style=filled, color=green];
    label = "The Ring I";
    m1 -- m2 -- m3 -- m4 -- m5 -- m1;
  }
  
  subgraph clusterQ{
    style=filled;
    color=brown;
    node [style=filled, color=brown];
    label = "The Ring II";
    q1 -- q2 -- q3 -- q4 -- q5 -- q6 -- q7 -- q8 -- q9 -- q1;
  }
  
  subgraph clusterS {
    style=filled;
    color=lightgrey;
    node [style=filled, color=grey];
    label = "The Ring III";
    s1 -- s2 -- s3 -- s4 -- s5 -- s6 -- s7 -- s8 -- s9 -- s10 -- s11 -- s1;
  }
  j8 -- h5;
  s9 -- h8;
  m1 -- h3;
  h2 -- q3;
}
EOF

# %%
cat merged.dot | circo -Tpng | display

# %%
cat merged.dot | circo -Tpng > merged.png
