# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/blood.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
                            param1=50,param2=30,minRadius=0,maxRadius=11)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2_imshow(cimg)
print("Minimal radius = {}. Maximum radius = {}".format(0,11))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FA53C429A90>
# Minimal radius = 0. Maximum radius = 11

# %%
img = cv2.imread('/content/cells.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
                            param1=50,param2=30,minRadius=0,maxRadius=15)
#circles = circles.float()
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2_imshow(cimg)
print("Minimal radius = {}. Maximum radius = {}".format(0,15))
# Out:
# <PIL.Image.Image image mode=RGB size=696x520 at 0x7FA53C5CC208>
# Minimal radius = 0. Maximum radius = 15

# %%
img = cv2.imread('/content/circles.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
                            param1=50,param2=30,minRadius=0,maxRadius=15)
#circles = circles.float()
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2_imshow(cimg)
print("Minimal radius = {}. Maximum radius = {}".format(0,15))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FA53C3A4358>
# Minimal radius = 0. Maximum radius = 15

# %%
img = cv2.imread('/content/cable.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
                            param1=50,param2=30,minRadius=7,maxRadius=28)
#circles = circles.float()
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2_imshow(cimg)
print("Minimal radius = {}. Maximum radius = {}".format(7,28))
# Out:
# <PIL.Image.Image image mode=RGB size=590x462 at 0x7FA53C55E630>
# Minimal radius = 7. Maximum radius = 28
